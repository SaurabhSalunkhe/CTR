# %%
import pandas as pd

# %%
path='/FileStore/tables/MLLib/train_for_MLlib.csv'

data=sqlContext.read.format("csv")\
        .option("header","true")\
        .option("inferSchmea","true")\
        .load(path)

display(data)

# %%
type(data)

# %%
my_data=pd.read_csv('/dbfs/FileStore/tables/MLLib/train_for_MLlib.csv')

# %%
type(my_data)

# %%
from keras.models import Sequential
from keras.layers import *

# %%
model = Sequential()
# since, i am creating a basic model , i am just utlizing 2 input parameters
model.add(Dense(50, input_dim=3, activation='relu'))
# adding two more layers
# doing trial and error with layers
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss="mean_squared_error", optimizer="adam")

# %%
from sklearn.cross_validation import train_test_split

X = my_data[['Position','SearchID', 'HistCTR']]
y = my_data.IsClick


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model.fit(
    X_train,
    y_train,
    epochs=50,
    shuffle=True,
    verbose=2
)

# %%
test_error_rate = model.evaluate(X_test, y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
